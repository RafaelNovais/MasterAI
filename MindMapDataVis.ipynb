# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaelNovais/MasterAI/blob/master/MindMapDataVis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Visualisation
#
# DATA + VISUAL ENCONDING ELEMENTS(Features) =DATA VISUALISATION
#
#
#
#
# # Types of Data Visualisation
#
# 1.   Data Analysis
#
#       Outlier BoxPlot/Whisker
#
#
# 2.   Discovery/Exploration
#
#       This is heatmap combined with two bargraphs
#       Audience = DataAnalysis Team
#       Extract Information from data
#
#
#       2.1 Variation
#         Analyse and visualise the distributions of value of your variables
#         Box-Plot
#
#       2.2 Co Variation
#         Anaqlyse and visualise the correlatrtions between your variable
#         Scatterplot
#
#
# 3.   Explanation
#
#     This is a diverging bar graph Very useful for showing how values diverge from a baseline value
#
#     Demostrate and present the outcome of your analysis or model to an external audience
#
#
#
# 4.   Decision Making
#
#
# 5.   Truthfulness
#
#
#
# # 4 Question to desing a visualisation
#
# 1 - Does the audience have the background to understand the visualisation
#
#     Nothing
#     A Little
#     Something but not expert
#     A lot
#     Expert
#
# 2 - How Much time have the audience got to digest/analisy you visualisation
#
#     Limited - Tv Show
#
#     Unlimited Print
#
# 3 - How much space do you have for your visualisation
#
#     Power Point Full Screen
#
#     Small Graphic in A4
#
# 4 - Will someone be present to explain/Highlight the Visualisation
#
#     Yes    Can be explained
#     Maybe
#     No     More details
#
#
#
# # Properties of Good Data Visualisation
#
#     1 - Trustful
#
#       Data Visualisation must always reflect the truth
#       Shouldn't select or omit data
#       Shouldn't Mislead or Obscure the information
#
#
#     2 - Functional
#
#       Use an appropriate graphic to communicate the information
#
#
#     3 - Insightful
#
#       Learn something from the graphic
#
#
#     4 - Enlightening
#
#       Additional context to explain the message
#
#     5 - Aesthetically Pleasing
#
#       Clearety
#
#
# # Visual Features
#
#     1 - Because the humam visual system is a pattern seeker of enormous power and subtlety
#
#     2 - Data visualisation is the presentation of data following perception-based rules
#
#     3 - Graphical excellence is that which gives to the viewer th greatest number of ideas in the shortes time with the least ink in the smallest space.
#
#     4 - Data Visualisation is the presentation of data following perception-based rules that allows a person to efficiently read and understand the key structures in the data.
#
#
# # Data Visualisation Should keep in Mind.
#
#     1. Serve a clear purpose: Description exploration tabulatio
#     2. Shows mulivariate data, that is show more than 1 or 2 variables
#     3. Makes a large data set coherent
#     4. Shows comparisons, contrasts, differences.
#     5. Shows causality, mechanism, explanation, systematic structure.
#     6. Integrates words, numbers, images, diagrams
#     7. Avoid distorting what the data has to say
#     8. Describe the evidence - title authors and sponsors, data sources, the measurement scales, points out relevant issues.
#
#
#
# # Aesthetic
#
# Types:
# 1. Shape,
# 2. Position,
# 3. Colours,
# 4. Line Width
# 5. Line Type
# 6. Size
#
# Definetion:
# 1. Aesthetics: visual features that can encode differences in value of quantitative or qualitative data
# 2. Typically a variable is linked to at least one aesthetic (generally no more than two)
# 3. As the values of the variable changes, so too should the visual qualities of the aesthetic change.
# 4. If the value of the variable is high - then we should be able to perceive this by looking at the visual property of the aesthetic.
# 5. The aesthetic provides a visual language by which to understand the values of the variable
#
# Visual Perception:
#
# * Visual perception is not a unidirectional progression from Stage 1 to Stage 3 processing
# * Information also flows from stage 3 to lower stages to consolidate and focus visual perception
# * The entire system is constantly being tuned from top to bottom based on our expectations and what is useful to us
# * This is known as attention
# * Even stage 1 features are subject to attention being tuned to be more sensitive to what is useful and interesting to us
#
# * Guidelines
#   - Data Visualisation must consider humam sensory capabilities so that important data elements and data patterns can be quickly perceived.
#   - Important data should be represented by graphical elements that are more visually distinct than those representing less important information.
#
# * Pre-Attentive Processing
#   - The eye is tuned to the detection of certain shapes, arrangements and colour combinations.
#   - This is called pre-attentive processing, and determines what visual object catch they eye's attention(and are easy to find in the next fixation)
#
#
# 1. Parallel Processing:
#   1. Rapid parallel processing of the visual scene
#   2. Extraction of features, orientation, colours, texture, and movement patterns
#   3. Informationi is head briefly in short term memory
#   4. To extract low level properties, feaures
#
# 2. Pattern Preception
#   1. Slower serial processing
#   2. Patterns established from the features identified from State 1
#   A small number (1 to 3) patterns becoming "bound" in memory and held for a second or two
#
# 3. Visual Working Memory
#   1. Highest level of perception
#   2. Objects are held in visal working memory by the demands of active attention
#   3. Attention is driven by a sequence of visual queries that are answered through visual search strategies
#   4. Only a few object can be held at a time
#   5. these are contructed from the available visual patterns that may provide answers to the visual query and from long term memory related to the task
#
#
# # Quantitative Colour scales
#
# 1. Sequential Colour Scale
#   * Sequence of colours that clearly indicate which values are larger/smaller
#
# 2. Diverging Colour Scale
#   * Distinctt colours on oposites ends of colours, contrast between positive and negative values
#
# # Qualitative Colour Scales
#
#   * Visualising distinct category values, no dominate
#   * Different Category
#   * Mistake is to try to represent too many category with different colours
#   * Mistake is use many colours from same scale, don't differenced
#
#
#
# #Graphical Elements
#
# Data Types
#
# 1. Categorial Values
#   1. Nominal - No order, no quantitative values
#   2. Ordinal - Have an order, but don't represent quantities
#   3. Interval - Have ann order, which refer to quantitative values are evenly spaced
#   4. Months - Dates, Ordinal+Interval
#
#
# 2. Quantitative Values
# Quantitative messages always involve showing the relationships between data variables
#   1. Nominal Comparison
#   2. Rankin Relationship
#
#
#
# # Proportions
#
# PIE Chart
# 1.   Show how somw group or amount breaks down into individual parts
# 2.   Show how each represents a part od whole
# 3.   Compare parts which are larger smaller and  the same
# 4.   Compare Proportions at different interval or observatioins
# 5.   Can take up a lot of space
# 6.   Impossible to make accurate comparison across multiple bar charts
#
#
# Stacked Bar Graphs
# 1.   Used for representing proportions within a bar and across bars
# 2.   The total value of the bar is given by the segment values added together.
# 3.
#
# Hierarchical Data
# 1.   Data is hierarchical and visualing the overall proportioins
# 2.   Tree Maps

# %% [markdown]
# 1.1 Provide a concise definition of data visualisation based on what you have
# learned in this module. [3]
# 1.2 Describe the 3-stage model of visual perception used in this module. [3]
# 1.3 What is pre-attentive visual perception and what is its relevance to data
# visualisation. [3]
# 1.4 Outline how you might check if your visualisation will appeal to the
# reader’s pre-attentive visual perception. [3]
# 1.5 Explain how an understanding of the Gestalt theory helps us in designing
# data visualisations.
#
# ```
# 1.1 Data visualization is the graphical representation of information and data, utilizing visual elements such as charts, graphs, and maps to help users understand complex datasets and uncover insights.
#
# 1.2 The 3-stage model of visual perception consists of:
#    1. Pre-attentive Processing: Rapid and automatic processing of visual stimuli before conscious awareness.
#    2. Focused Attention: Deliberate and conscious processing of visual stimuli, where attention is directed to specific features or regions.
#    3. Cognitive Processing: Interpretation and understanding of visual information, integrating it with existing knowledge and context.
#
# 1.3 Pre-attentive visual perception refers to the subconscious processing of visual stimuli, where certain visual features such as color, size, and orientation are quickly and effortlessly perceived before conscious attention is applied. Its relevance to data visualization lies in its ability to attract attention and convey information efficiently.
#
# 1.4 To check if a visualization appeals to pre-attentive visual perception, one can:
#    - Evaluate the use of pre-attentive attributes such as color, size, and shape to encode important data points.
#    - Conduct rapid perception tests to determine if key information can be quickly and accurately perceived without focused attention.
#    - Seek feedback from users to assess the effectiveness of the visualization in conveying information at a glance.
#
# 1.5 Understanding the Gestalt theory helps in designing data visualizations by providing principles that govern how humans perceive and organize visual elements. These principles include:
#    - Proximity: Objects that are close to each other are perceived as a group.
#    - Similarity: Objects with similar attributes are perceived as belonging together.
#    - Continuity: Lines or patterns that follow a smooth, continuous path are perceived as connected.
#    - Closure: Incomplete shapes are perceived as complete objects.
#    - Figure-ground: Distinguishing between the foreground and background to focus attention.
#    By applying these principles, data visualizations can be structured to enhance clarity, organization, and the overall comprehension of information presented.
# ```
