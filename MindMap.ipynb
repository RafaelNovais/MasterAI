# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaelNovais/MasterAI/blob/master/MindMap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1 Duck typing**
#
# means the same code can run with different types, as long as they have the right
# behaviour, which is determined at runtime.
# def hist(s):
# d = collections.defaultdict(int)
# for x in s:
# d[x] += 1
# return d
# Here, it doesn’t matter whether s is a list, set, tuple, string, or something else, as long as we
# can iterate over it. Grading: +3 for explanation, +2 for code.
#
#
# **2 -Memoisation means** (1)
#
# storing the result of every call to a function so that if it is ever called
# again with the same arguments, the result can be looked-up and returned without re-calculating
# it, (1) to save time. In order to be useful, (1) the function must be called repeatedly; there
# must be the possibility that it will be called repeatedly with the same arguments; (1) it must
# be relatively time-consuming; (1) it must be deterministic.
#
#
# **3 - Lambda x: x*0.3**
# soma_lambda = lambda numero1, numero2: numero1 + numero2  # Função soma escrita como Função Lambda
#
# **4 Supervizionada**
#
# 4.1 - Regression
# Regressao e quando vc tenta prever um valor especifico um valor numerico (Preco, Dado Numerico, Idade, Metro )
# 	4.1.1 - Regressao Lienar identificar um valor de imovel Best Line, uma linha entre x e y
# 			Multiple Linaer -  multiple independent variables. In this context, the goal is to model the relationship between multiple features (independent variables) and a target variable (dependent variable)
# 			Polynomial Nao linear um arco no grafico
#
# 	4.1.2 - Decison Tree  Contra Oferfiting ,
# 			Nodes
# 			ID3 is slower Melhor Atributo/Ganho de Informacao
# 			The ID3 (Iterative Dichotomiser 3) algorithm is a classic decision tree algorithm used for inducing decision trees from examples in machine learning. The goal is to create a tree structure that recursively splits the data based on the most informative features.
# 			Entropy is a measure of impurity or disorder in the dataset. A higher entropy indicates more disorder.
# 			C4.5 is fast  é  um  aprimoramento  do  algoritmo  ID3,
#
#
# 	4.1.3 - Random Forests
# 			Mutiple Decision Tree
#
# 	4.1.4 - Neural Net Work
# 			Input > Hidden > Output Layer
#
# 	4.1.5 -	AdaBoost Fraude de cartao
#
# 	4.1.6 - Gradient Boost
#
#
# 4.2- Classification - Classificacao encontra a classe output discrete    ( Tem doenca ou nao tem , email e span ou nao e spam, perfil de cliente )
# 	4.2.1 - Regressao logistica   Valores de saidas binarios risco em seguradoras output 0/1, predict Probabiliiti ODDs
#
# 	4.2.2 - Suport Vector Machine - Find a Hiperline N-Dimensional space that distinctly classifies data points
# 		Hyperplanes
# 		Kernels
#
# 	4.2.3 - Naive Bayes Probabilisto
# 			Filtros de Spam/ Grau de satisfacao/separacao de documentos
# 			Mineracao de texto/Tabela de probabilidade
#
# 	4.2.4 - Decision Tree, Random Forest, Neural Net work but the Output is discrete
#
# 	4.2.5 - K-Near Neighbours Distance Metric
#
#
# **5 Nao Supervizionada**
#
# 5.1 - Clustering - separa em grupos, Segmentation
# 	5.1.1 - K-means
#
# 	5.1.2 - Hierarchical
#
# 	5.1.3 - Mean Shift
#
# 	5.1.4 - Density-Based
#
#
#
# 5.2 - Dimensionality Redunction  - Process of reduction the dimensioni of your feature set PCA - PRINCIPAL COMPONENT ANALYSIS
#
# 	5.2.1 - Feature Elimination
#
# 	5.2.2 - Feature Extraction
#
#
#
# **6 - Verifica dado/ Normalization**
#
# 	6.1 - Dados nulos ou vazio
#
# 	6.2 - Kbest pontua as melhores features
# 		6.2.1 - Predictive  Useful information when estimating correct target
# 		6.2.2 - Interacting Useful information only when considered in conjuction with other features
# 		6.2.3 - Redundant 	Strong correlation with another feature
# 		6.2.4 - Irrelevant 	Not important
#
#
# 	Verifica correlacao entre dados
# 	Rescale all dimensions independently
#
#
#
# **7 - Similarity-based Learning**
#
# 	7.1 Metric
# 		Euclidian
# 		Manhttan  - Cheaper nor necessary squares Large dataset
# 		Minkoeski -  Many distance metric
#
# 	7.2 Cosine Similarity
# 		Index may be used to measure the similarity of two instances CONTINUOUS ATTRIBUTES
# 		INNER ANGLE BETWEN 2 VECTOR
#
#
#
# **8 - hypothesis language,overfitting, underfitting and noise**
#
# 	8.1 - Hypothesis Language
# 		 a hypothesis language represents the set of all possible hypotheses or functions that a model can learn.
#
# 	8.2 - Overfitting
# 		Modelo foi treinado muito especifico porem nao certa no teste, Viciado com o treino
# 		Muito ajustado com os dados de treino, mas com test nao prever bem
#
#
# 	8.3 - Underfitting
# 		Nao e ajustado nem no treino nem no test, EX utilizar modelo de Reta/Linear no modelo de curva
# 		Nao foi treinado corretamente nao prever correto / Abaixo do modelado
#
# 	8.4 - Noise
#
#
# **9 - Learning Algorithms**
#
# 	9.1 - Lazy - KNN
# 		Learning from your neighbors / Simply /Training Data / Test Tuple
# 		Fast time training but Slow time in predicting
# 		Accuracy
#
# 	9.2 - Eager - Linear Regression, Logistic Regression, Support Vector Machines, Decision Trees, and Artificial Neural Networks.
# 		Contructs a classification model
# 		build a model based
# 		Slow time training but Fast time predicting
#
#
# **10 - curse of dimensionality**
# Feature Selection
# 	10.1 - The "Curse of Dimensionality" refers to the challenges and issues that arise when dealing with high-dimensional data in machine learning tasks. As the number of features or dimensions in the dataset increases, various problems emerge, impacting the efficiency and performance of machine learning algorithms.
# 	10.2 - Increased Data Sparsity:
# 	10.3 - Computational Complexity
#
#
# **11- Reinforcement Learning/MDPs Aprendizagem (Carro Autonomo )**
#
# 	Ambiente + Agente + Acao + Estado + Policy  / estado atual futuro e passado sao independentes
# 	infinity Choises / Nao e historico
# 	Equacao de bellman
#
# 	11.1 - Markov Decision Process, Previsao do Tempo (B - A - B = 0.18 ou B - B -B = 0.16)
# 			the future is conditionally independent of the past given the present.
# 			A - A = 0.7
# 			A - B = 0.3
# 			B - B = 0.4
# 			B - A = 0.6
#
# 	11.2 - Q-Learning Algorithm,
# 			Q-value represents the expected cumulative reward an agent would receive by taking a specific action in a particular state and following a certain policy thereafter
#
# 			11.2.1 - Exploit  O agente seleciona a ação com base no valor máximo dessas ações.usar a tabela q como referência e visualizar todas as ações possíveis para um determinado estado.
# 			11.2.2 - Explore  é agir aleatoriamente. explorar e descobrir novos estados
# 			11.2.3 - Learning rate Relevancia das recompencas atuais / Velocidade de aprendizado / Taxa menor +tempo +detalhes /Taxa Maior -Tempo - detalhe
# 			11.2.4 - Discount factor Permite ao agente selecionar as acoes na tentativa de maximizar a soma de recompensas no futuro / A factor that is multiplied to future reward to get it present, fututure reward worth than immediate <1 Serve para reduzir o premio com o tempo ajudando a mapear mais rapido
#
# 	11.3 - Reward-Based Learning Reforço Recompensa Positiva e Negativa
# 			 11.3.1 - Living Penalty - Nao pode ser auto para nao suicidar, nao pode ser baixo para ficar passeando no ambiente  Recompensa Positiva e Negativa
# 			 11.3.2 - Policy Is the strategy that the agente employs to determine its action based on the current state, Policy can be thought of as a function or mapfromo states to action
#
#
#
#
# **12 - Cross-validation**
# 	12.1 - K-fold Varios Split Train Test e acha a media
#
#
# **13- compute performance measures, learning curves and ROC graphs**
#
# 	13.1
# 	13.2 - Confusion Matrix
# 			VerdPositivo FalsoNegativo
# 			FalsoPositiv VerdNegativo
# 			Precison is the proporttion correctly classified
# 	13.3 - ROC - Is Graphic to help to find best Threshold, summarizes all of confusion matrices
# 			Threshold corte do grafico move to apprimorate
# 			distance from linear is better
# 	13.4 - AUC - Area under the curve
# 			Compare 2  ROC like ROC from Logistic Regression is better than ROC from random forest
#
#
# **14- Feature Scaling, Kbest, feature**
#
#
# **15- prior and conditional probability, axioms of probability and Bayes' rule**
#
# 	Bayes’ Rule: Example
# 	Naïve Bayes Classifier
#
#
# **16 - Variable**
#
# 	16.1 - Quantitativa (Numero)
# 		16.1.1 - Discreta - Numero Natural (inteiro, 0,5 nao faz sentido) Numero de filhos
# 		16.1.2 - Continua - Numero Decimal (Float 0,5 FAZ Sentido) Renda, dinheiro
#
# 	16.2 - Qualitativa - (Palavra)
# 		16.2.1 - Ordinal - Uma Ordenacao Escolaridade melhor e pior
# 		16.2.2 - Nominal - NAO tem ordem - Tipo Sange
